# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
from pandas import DataFrame, Series
import sklearn
import numpy as np

# %% [markdown]
# ### Download housing Data

# %%
import os
import tarfile
from six.moves import urllib

DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml/master/"
HOUSING_PATH = "datasets/housing"
HOUSING_URL = DOWNLOAD_ROOT + HOUSING_PATH + "/housing.tgz"

def fetch_housing_data(housing_url=HOUSING_URL, housing_path=HOUSING_PATH):
    if not os.path.isdir(housing_path):
        os.makedirs(housing_path)
    tgz_path = os.path.join(housing_path, "housing.tgz")
    urllib.request.urlretrieve(housing_url, tgz_path)
    housing_tgz = tarfile.open(tgz_path)
    housing_tgz.extractall(path=housing_path)
    housing_tgz.close()
fetch_housing_data()

# %%
def load_housing_data(housing_path=HOUSING_PATH):
    csv_path = os.path.join(housing_path, "housing.csv")
    return pd.read_csv(csv_path)

# %%
housing = load_housing_data()
housing.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# 5       413.0       193.0         4.0368            269700.0        NEAR BAY
# 6      1094.0       514.0         3.6591            299200.0        NEAR BAY
# 7      1157.0       647.0         3.1200            241400.0        NEAR BAY
# 8      1206.0       595.0         2.0804            226700.0        NEAR BAY
# 9      1551.0       714.0         3.6912            261100.0        NEAR BAY

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
# longitude             20640 non-null float64
# latitude              20640 non-null float64
# housing_median_age    20640 non-null float64
# total_rooms           20640 non-null float64
# total_bedrooms        20433 non-null float64
# population            20640 non-null float64
# households            20640 non-null float64
# median_income         20640 non-null float64
# median_house_value    20640 non-null float64
# ocean_proximity       20640 non-null object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
housing["ocean_proximity"].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
# %matplotlib inline  
import matplotlib.pyplot as plt
housing.hist(bins=50, figsize=(20,15))
plt.show()

# %%
from sklearn.cross_validation import train_test_split

train_set, test_set = train_test_split(housing, test_size=0.2, random_state=42)

# %%
print train_set.shape, test_set.shape
# Out:
# (16512, 10) (4128, 10)

# %% [markdown]
# ### Stratifying Sampling data

# %%
housing["income_cat"] = np.ceil(housing["median_income"] / 1.5)
housing["income_cat1"] = housing["income_cat"]
housing["income_cat1"].where(housing["income_cat1"] < 5, 5.0, inplace=True)

# %%
housing.head(20)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.23     37.88                41.0        880.0           129.0
# 1     -122.22     37.86                21.0       7099.0          1106.0
# 2     -122.24     37.85                52.0       1467.0           190.0
# 3     -122.25     37.85                52.0       1274.0           235.0
# 4     -122.25     37.85                52.0       1627.0           280.0
# 5     -122.25     37.85                52.0        919.0           213.0
# 6     -122.25     37.84                52.0       2535.0           489.0
# 7     -122.25     37.84                52.0       3104.0           687.0
# 8     -122.26     37.84                42.0       2555.0           665.0
# 9     -122.25     37.84                52.0       3549.0           707.0
# 10    -122.26     37.85                52.0       2202.0           434.0
# 11    -122.26     37.85                52.0       3503.0           752.0
# 12    -122.26     37.85                52.0       2491.0           474.0
# 13    -122.26     37.84                52.0        696.0           191.0
# 14    -122.26     37.85                52.0       2643.0           626.0
# 15    -122.26     37.85                50.0       1120.0           283.0
# 16    -122.27     37.85                52.0       1966.0           347.0
# 17    -122.27     37.85                52.0       1228.0           293.0
# 18    -122.26     37.84                50.0       2239.0           455.0
# 19    -122.27     37.84                52.0       1503.0           298.0
#
#     population  households  median_income  median_house_value ocean_proximity  \
# 0        322.0       126.0         8.3252            452600.0        NEAR BAY
# 1       2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2        496.0       177.0         7.2574            352100.0        NEAR BAY
# 3        558.0       219.0         5.6431            341300.0        NEAR BAY
# 4        565.0       259.0         3.8462            342200.0        NEAR BAY
# 5        413.0       193.0         4.0368            269700.0        NEAR BAY
# 6       1094.0       514.0         3.6591            299200.0        NEAR BAY
# 7       1157.0       647.0         3.1200            241400.0        NEAR BAY
# 8       1206.0       595.0         2.0804            226700.0        NEAR BAY
# 9       1551.0       714.0         3.6912            261100.0        NEAR BAY
# 10       910.0       402.0         3.2031            281500.0        NEAR BAY
# 11      1504.0       734.0         3.2705            241800.0        NEAR BAY
# 12      1098.0       468.0         3.0750            213500.0        NEAR BAY
# 13       345.0       174.0         2.6736            191300.0        NEAR BAY
# 14      1212.0       620.0         1.9167            159200.0        NEAR BAY
# 15       697.0       264.0         2.1250            140000.0        NEAR BAY
# 16       793.0       331.0         2.7750            152500.0        NEAR BAY
# 17       648.0       303.0         2.1202            155500.0        NEAR BAY
# 18       990.0       419.0         1.9911            158700.0        NEAR BAY
# 19       690.0       275.0         2.6033            162900.0        NEAR BAY
#
#     income_cat  income_cat1
# 0          6.0          5.0
# 1          6.0          5.0
# 2          5.0          5.0
# 3          4.0          4.0
# 4          3.0          3.0
# 5          3.0          3.0
# 6          3.0          3.0
# 7          3.0          3.0
# 8          2.0          2.0
# 9          3.0          3.0
# 10         3.0          3.0
# 11         3.0          3.0
# 12         3.0          3.0
# 13         2.0          2.0
# 14         2.0          2.0
# 15         2.0          2.0
# 16         2.0          2.0
# 17         2.0          2.0
# 18         2.0          2.0
# 19         2.0          2.0

# %%
housing["income_cat"].value_counts()
# Out:
# 3.0     7236
# 2.0     6581
# 4.0     3639
# 5.0     1423
# 1.0      822
# 6.0      532
# 7.0      189
# 8.0      105
# 9.0       50
# 11.0      49
# 10.0      14
# Name: income_cat, dtype: int64

# %%
housing["income_cat"].value_counts() / len(housing)
# Out:
# 3.0     0.350581
# 2.0     0.318847
# 4.0     0.176308
# 5.0     0.068944
# 1.0     0.039826
# 6.0     0.025775
# 7.0     0.009157
# 8.0     0.005087
# 9.0     0.002422
# 11.0    0.002374
# 10.0    0.000678
# Name: income_cat, dtype: float64

# %%
housing = train_set.copy()
housing.plot(kind="scatter", x="longitude", y="latitude")

# %% [markdown]
# #### Setting the alpha option to 0.1 makes it much easier to visualize the places where there is a high density of data points

# %%
housing.plot(kind="scatter", x="longitude", y="latitude", alpha=0.1)

# %% [markdown]
# #### Comparing house price based on locations

# %%
housing.plot(kind="scatter", x="longitude", y="latitude", alpha=0.5,
    s=housing["population"]/100, label="population",
    c="median_house_value", cmap=plt.get_cmap("jet"), colorbar=True,
)
plt.legend()

# %%
corr_matrix = housing.corr()

# %%
corr_matrix
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924485           -0.101818     0.038676
# latitude            -0.924485  1.000000            0.005296    -0.029224
# housing_median_age  -0.101818  0.005296            1.000000    -0.360922
# total_rooms          0.038676 -0.029224           -0.360922     1.000000
# total_bedrooms       0.063064 -0.059998           -0.320624     0.930489
# population           0.094276 -0.102499           -0.292283     0.857936
# households           0.049306 -0.064061           -0.302796     0.920482
# median_income       -0.017040 -0.076571           -0.121711     0.198268
# median_house_value  -0.046349 -0.142983            0.103706     0.133989
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.063064    0.094276    0.049306      -0.017040
# latitude                 -0.059998   -0.102499   -0.064061      -0.076571
# housing_median_age       -0.320624   -0.292283   -0.302796      -0.121711
# total_rooms               0.930489    0.857936    0.920482       0.198268
# total_bedrooms            1.000000    0.878932    0.980255      -0.009141
# population                0.878932    1.000000    0.907452       0.004122
# households                0.980255    0.907452    1.000000       0.012776
# median_income            -0.009141    0.004122    0.012776       1.000000
# median_house_value        0.047980   -0.026032    0.063714       0.690647
#
#                     median_house_value
# longitude                    -0.046349
# latitude                     -0.142983
# housing_median_age            0.103706
# total_rooms                   0.133989
# total_bedrooms                0.047980
# population                   -0.026032
# households                    0.063714
# median_income                 0.690647
# median_house_value            1.000000

# %%
from pandas.tools.plotting import scatter_matrix

attributes = ["median_house_value", "median_income", "total_rooms",
              "housing_median_age"]
scatter_matrix(housing[attributes], figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1249c14d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124ec4110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124e88250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f662950>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11f6e4a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f6860d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f7d3c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12593abd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1259ac310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125a2f290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125a923d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125b13450>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x125b4a610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122c44e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125be2610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125c454d0>]], dtype=object)

# %% [markdown]
# #### Attribute Combinations

# %%
housing["rooms_per_household"] = housing["total_rooms"]/housing["households"]
housing["bedrooms_per_room"] = housing["total_bedrooms"]/housing["total_rooms"]
housing["population_per_household"]=housing["population"]/housing["households"]

# %%
housing.head(10)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14196    -117.03     32.71                33.0       3126.0           627.0
# 8267     -118.16     33.77                49.0       3382.0           787.0
# 17445    -120.48     34.66                 4.0       1897.0           331.0
# 14265    -117.11     32.69                36.0       1421.0           367.0
# 2271     -119.80     36.78                43.0       2382.0           431.0
# 17848    -121.86     37.42                20.0       5032.0           808.0
# 6252     -117.97     34.04                28.0       1686.0           417.0
# 9389     -122.53     37.91                37.0       2524.0           398.0
# 6113     -117.90     34.13                 5.0       1126.0           316.0
# 6061     -117.79     34.02                 5.0      18690.0          2862.0
#
#        population  households  median_income  median_house_value  \
# 14196      2300.0       623.0         3.2596            103000.0
# 8267       1314.0       756.0         3.8125            382100.0
# 17445       915.0       336.0         4.1563            172600.0
# 14265      1418.0       355.0         1.9425             93400.0
# 2271        874.0       380.0         3.5542             96500.0
# 17848      2695.0       801.0         6.6227            264800.0
# 6252       1355.0       388.0         2.5192            157300.0
# 9389        999.0       417.0         7.9892            500001.0
# 6113        819.0       311.0         1.5000            139800.0
# 6061       9427.0      2777.0         6.4266            315600.0
#
#       ocean_proximity  rooms_per_household  bedrooms_per_room  \
# 14196      NEAR OCEAN             5.017657           0.200576
# 8267       NEAR OCEAN             4.473545           0.232703
# 17445      NEAR OCEAN             5.645833           0.174486
# 14265      NEAR OCEAN             4.002817           0.258269
# 2271           INLAND             6.268421           0.180940
# 17848       <1H OCEAN             6.282147           0.160572
# 6252        <1H OCEAN             4.345361           0.247331
# 9389         NEAR BAY             6.052758           0.157686
# 6113        <1H OCEAN             3.620579           0.280639
# 6061        <1H OCEAN             6.730284           0.153130
#
#        population_per_household
# 14196                  3.691814
# 8267                   1.738095
# 17445                  2.723214
# 14265                  3.994366
# 2271                   2.300000
# 17848                  3.364544
# 6252                   3.492268
# 9389                   2.395683
# 6113                   2.633441
# 6061                   3.394671

# %%
corr_matrix = housing.corr()
corr_matrix
# Out:
#                           longitude  latitude  housing_median_age  \
# longitude                  1.000000 -0.924485           -0.101818
# latitude                  -0.924485  1.000000            0.005296
# housing_median_age        -0.101818  0.005296            1.000000
# total_rooms                0.038676 -0.029224           -0.360922
# total_bedrooms             0.063064 -0.059998           -0.320624
# population                 0.094276 -0.102499           -0.292283
# households                 0.049306 -0.064061           -0.302796
# median_income             -0.017040 -0.076571           -0.121711
# median_house_value        -0.046349 -0.142983            0.103706
# rooms_per_household       -0.029339  0.110695           -0.160892
# bedrooms_per_room          0.097280 -0.118938            0.135495
# population_per_household  -0.000598  0.005837            0.016245
#
#                           total_rooms  total_bedrooms  population  households  \
# longitude                    0.038676        0.063064    0.094276    0.049306
# latitude                    -0.029224       -0.059998   -0.102499   -0.064061
# housing_median_age          -0.360922       -0.320624   -0.292283   -0.302796
# total_rooms                  1.000000        0.930489    0.857936    0.920482
# total_bedrooms               0.930489        1.000000    0.878932    0.980255
# population                   0.857936        0.878932    1.000000    0.907452
# households                   0.920482        0.980255    0.907452    1.000000
# median_income                0.198268       -0.009141    0.004122    0.012776
# median_house_value           0.133989        0.047980   -0.026032    0.063714
# rooms_per_household          0.136090       -0.001659   -0.073733   -0.083062
# bedrooms_per_room           -0.189316        0.084149    0.035134    0.064185
# population_per_household    -0.024991       -0.028536    0.072330   -0.027656
#
#                           median_income  median_house_value  \
# longitude                     -0.017040           -0.046349
# latitude                      -0.076571           -0.142983
# housing_median_age            -0.121711            0.103706
# total_rooms                    0.198268            0.133989
# total_bedrooms                -0.009141            0.047980
# population                     0.004122           -0.026032
# households                     0.012776            0.063714
# median_income                  1.000000            0.690647
# median_house_value             0.690647            1.000000
# rooms_per_household            0.336013            0.158485
# bedrooms_per_room             -0.616669           -0.257419
# population_per_household       0.022061           -0.022030
#
#                           rooms_per_household  bedrooms_per_room  \
# longitude                           -0.029339           0.097280
# latitude                             0.110695          -0.118938
# housing_median_age                  -0.160892           0.135495
# total_rooms                          0.136090          -0.189316
# total_bedrooms                      -0.001659           0.084149
# population                          -0.073733           0.035134
# households                          -0.083062           0.064185
# median_income                        0.336013          -0.616669
# median_house_value                   0.158485          -0.257419
# rooms_per_household                  1.000000          -0.435169
# bedrooms_per_room                   -0.435169           1.000000
# population_per_household            -0.004922           0.003938
#
#                           population_per_household
# longitude                                -0.000598
# latitude                                  0.005837
# housing_median_age                        0.016245
# total_rooms                              -0.024991
# total_bedrooms                           -0.028536
# population                                0.072330
# households                               -0.027656
# median_income                             0.022061
# median_house_value                       -0.022030
# rooms_per_household                      -0.004922
# bedrooms_per_room                         0.003938
# population_per_household                  1.000000

# %%
corr_matrix["median_house_value"].sort_values(ascending=False)
# Out:
# median_house_value          1.000000
# median_income               0.690647
# rooms_per_household         0.158485
# total_rooms                 0.133989
# housing_median_age          0.103706
# households                  0.063714
# total_bedrooms              0.047980
# population_per_household   -0.022030
# population                 -0.026032
# longitude                  -0.046349
# latitude                   -0.142983
# bedrooms_per_room          -0.257419
# Name: median_house_value, dtype: float64

# %% [markdown]
# #### Visualizing correlation matrix

# %%
import seaborn as sns

sns.heatmap(corr_matrix,xticklabels=corr_matrix.columns.values,yticklabels=corr_matrix.columns.values)
#sns.heatmap(corr_matrix, mask=np.zeros_like(corr_matrix, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
#            square=True)

# %% [markdown]
# ### Data Preparation

# %%
housing = train_set.drop("median_house_value", axis=1)
housing_labels = train_set["median_house_value"].copy()

# %%
housing["total_bedrooms"].median()
# Out:
# 437.0

# %%
# missing values
from sklearn.preprocessing import Imputer

imputer = Imputer(strategy="median")
housing_num = housing.drop("ocean_proximity", axis=1)
imputer.fit(housing_num)
housing_num.head(100)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14196    -117.03     32.71                33.0       3126.0           627.0
# 8267     -118.16     33.77                49.0       3382.0           787.0
# 17445    -120.48     34.66                 4.0       1897.0           331.0
# 14265    -117.11     32.69                36.0       1421.0           367.0
# 2271     -119.80     36.78                43.0       2382.0           431.0
# 17848    -121.86     37.42                20.0       5032.0           808.0
# 6252     -117.97     34.04                28.0       1686.0           417.0
# 9389     -122.53     37.91                37.0       2524.0           398.0
# 6113     -117.90     34.13                 5.0       1126.0           316.0
# 6061     -117.79     34.02                 5.0      18690.0          2862.0
# 16030    -122.45     37.72                52.0        982.0           197.0
# 8364     -118.35     33.97                25.0       1864.0           616.0
# 9448     -119.72     37.46                13.0       1999.0           375.0
# 17529    -121.88     37.33                36.0       1904.0           689.0
# 5865     -118.34     34.18                46.0       1393.0           301.0
# 7615     -118.23     33.89                36.0       2598.0           514.0
# 9707     -121.65     36.67                52.0       2351.0           459.0
# 16332    -121.34     38.03                20.0       4213.0           751.0
# 3449     -118.43     34.32                34.0       2657.0           515.0
# 5199     -118.28     33.93                21.0        847.0           278.0
# 13496    -117.34     34.16                31.0       1606.0           354.0
# 18056    -121.98     37.24                35.0       3574.0           485.0
# 9529     -123.15     38.94                22.0       2163.0           436.0
# 5128     -118.28     33.98                43.0       1240.0           312.0
# 18796    -122.31     40.89                18.0        754.0           161.0
# 413      -122.28     37.89                52.0       2070.0           329.0
# 1175     -121.57     39.48                15.0        202.0            54.0
# 4387     -118.26     34.08                46.0        945.0           250.0
# 11628    -118.07     33.80                22.0       1391.0           338.0
# 9787     -120.79     36.06                29.0       1916.0           386.0
# ...          ...       ...                 ...          ...             ...
# 17189    -122.27     37.32                37.0       2607.0           534.0
# 8126     -118.18     33.81                27.0        471.0           132.0
# 14128    -117.09     32.75                28.0       1220.0           391.0
# 17777    -121.85     37.38                12.0      12980.0          2568.0
# 12914    -121.32     38.61                22.0       3902.0           845.0
# 16257    -121.25     37.97                34.0       1288.0           344.0
# 11135    -117.93     33.84                23.0       2870.0           653.0
# 13987    -117.13     34.88                21.0       3254.0           669.0
# 7711     -118.14     33.95                36.0       1942.0           355.0
# 18591    -122.13     36.97                27.0        991.0           194.0
# 6529     -118.06     34.06                28.0       2127.0           625.0
# 483      -122.27     37.86                52.0       1769.0           372.0
# 3846     -118.47     34.19                41.0       1104.0           196.0
# 12826    -121.44     38.71                25.0       2336.0           406.0
# 1315     -121.79     37.99                18.0       3646.0           534.0
# 7222     -118.17     34.02                42.0        946.0           272.0
# 14016    -117.16     32.75                23.0       2474.0           594.0
# 4226     -118.29     34.10                39.0       2196.0           582.0
# 9279     -122.60     38.11                23.0       8642.0          1294.0
# 1576     -121.99     37.81                17.0        465.0            83.0
# 11301    -117.91     33.78                26.0       4297.0          1037.0
# 16519    -121.21     37.80                45.0        370.0            84.0
# 16394    -121.25     38.03                29.0       2465.0           327.0
# 5290     -118.49     34.05                45.0       1346.0           214.0
# 10353    -117.67     33.63                 9.0       5774.0          1320.0
# 11471    -118.00     33.67                34.0       3712.0           667.0
# 11886    -117.37     33.99                44.0        917.0           224.0
# 1989     -119.79     36.73                52.0        112.0            28.0
# 16457    -121.29     38.13                20.0       3168.0           514.0
# 8063     -118.19     33.83                43.0       2641.0           411.0
#
#        population  households  median_income
# 14196      2300.0       623.0         3.2596
# 8267       1314.0       756.0         3.8125
# 17445       915.0       336.0         4.1563
# 14265      1418.0       355.0         1.9425
# 2271        874.0       380.0         3.5542
# 17848      2695.0       801.0         6.6227
# 6252       1355.0       388.0         2.5192
# 9389        999.0       417.0         7.9892
# 6113        819.0       311.0         1.5000
# 6061       9427.0      2777.0         6.4266
# 16030       653.0       171.0         4.2167
# 8364       1710.0       575.0         2.2303
# 9448        750.0       308.0         2.8750
# 17529      3561.0       632.0         2.0972
# 5865        714.0       295.0         2.8125
# 7615       1872.0       514.0         3.1667
# 9707       1169.0       439.0         2.8924
# 16332      2071.0       714.0         4.4063
# 3449       1948.0       532.0         4.2330
# 5199       1283.0       277.0         1.4329
# 13496      1049.0       335.0         2.1935
# 18056      1325.0       476.0         8.5425
# 9529       1048.0       358.0         2.7171
# 5128       1100.0       311.0         1.5750
# 18796       247.0       107.0         2.2583
# 413         722.0       306.0         5.4171
# 1175        145.0        40.0         0.8252
# 4387        910.0       252.0         3.5039
# 11628       810.0       295.0         3.8792
# 9787       1019.0       314.0         2.4881
# ...           ...         ...            ...
# 17189      1346.0       507.0         5.3951
# 8126        315.0        96.0         1.7500
# 14128      1286.0       396.0         1.2286
# 17777      8190.0      2515.0         5.2415
# 12914      1870.0       763.0         2.7740
# 16257       846.0       293.0         1.7895
# 11135      1680.0       598.0         3.2301
# 13987      1548.0       545.0         2.3373
# 7711        891.0       348.0         3.6635
# 18591       543.0       155.0         4.7188
# 6529       3160.0       620.0         2.5763
# 483         849.0       365.0         2.6914
# 3846        495.0       196.0         5.0929
# 12826      1172.0       408.0         3.5129
# 1315       1651.0       535.0         5.7321
# 7222       1191.0       261.0         2.4500
# 14016      1107.0       536.0         2.9705
# 4226       1165.0       538.0         2.9417
# 9279       3594.0      1253.0         5.3962
# 1576        146.0        75.0         4.9018
# 11301      3596.0       967.0         3.0450
# 16519       167.0        70.0         1.4853
# 16394       859.0       315.0         6.6605
# 5290        415.0       209.0         7.0285
# 10353      3086.0      1265.0         4.4063
# 11471      1521.0       632.0         4.8125
# 11886       666.0       220.0         1.6850
# 1989        193.0        40.0         1.9750
# 16457      1390.0       490.0         5.0000
# 8063       1011.0       444.0         6.4468
#
# [100 rows x 8 columns]

# %%
X = imputer.transform(housing_num)
X
# Out:
# array([[ -1.17030000e+02,   3.27100000e+01,   3.30000000e+01, ...,
#           2.30000000e+03,   6.23000000e+02,   3.25960000e+00],
#        [ -1.18160000e+02,   3.37700000e+01,   4.90000000e+01, ...,
#           1.31400000e+03,   7.56000000e+02,   3.81250000e+00],
#        [ -1.20480000e+02,   3.46600000e+01,   4.00000000e+00, ...,
#           9.15000000e+02,   3.36000000e+02,   4.15630000e+00],
#        ...,
#        [ -1.18380000e+02,   3.40300000e+01,   3.60000000e+01, ...,
#           1.75600000e+03,   5.27000000e+02,   2.93440000e+00],
#        [ -1.21960000e+02,   3.75800000e+01,   1.50000000e+01, ...,
#           1.77700000e+03,   5.59000000e+02,   5.71920000e+00],
#        [ -1.22420000e+02,   3.77700000e+01,   5.20000000e+01, ...,
#           2.61900000e+03,   1.24200000e+03,   2.57550000e+00]])
